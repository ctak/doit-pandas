# %%
import seaborn as sns

tips = sns.load_dataset('tips')

# %%
import matplotlib.pyplot as plt

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], kde=False)
ax.set_title('Total Bill Histgram with Density Plot')
# Out:
# C:\Users\tak\AppData\Local\Temp\ipykernel_4772\3526584572.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], kde=False)
# Text(0.5, 1.0, 'Total Bill Histgram with Density Plot')

# %%
ax = sns.displot(tips['total_bill'])

# %%
ax = sns.histplot(tips['total_bill'])

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist=False)
ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')
# Out:
# C:\Users\tak\AppData\Local\Temp\ipykernel_4772\1639492382.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], hist=False)
# Text(0, 0.5, 'Unit Probability')

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug=True)
ax.set_title('Total Bill Histgram with Density and Rug Plot')
ax.set_xlabel('Total Bill')
# Out:
# C:\Users\tak\AppData\Local\Temp\ipykernel_4772\2752448189.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], rug=True)
# Text(0.5, 0, 'Total Bill')

# %%
ax = plt.subplots()
ax = sns.countplot(x='day', data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=True)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips)
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
ax = plt.subplots()
ax = sns.kdeplot(x=tips['total_bill'],
                 y=tips['tip'],
                 fill=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
# 바 그래프 그리기

ax = plt.subplots()
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %%
ax = plt.subplots()
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', data=tips)
ax.set_title('Violin plot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = sns.pairplot(tips)

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.distplot, rug=True)
plt.show()
# Out:
# C:\Users\tak\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# C:\Users\tak\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# C:\Users\tak\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1550: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)

# %%
# 다변량 그래프는 남녀 tip 의 차이을 보여주는 것이었다. 

ax_sns = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)

# %%
sns.pairplot(tips, hue='sex')

# %% [markdown]
# # seaborn regplot vs lmplot
#
# ## https://jehyunlee.github.io/2022/06/06/Python-DS-103-snsreglmplot/

# %%
# %matplotlib inline

# 시각화 설정
sns.set_context('talk')
sns.set_style('ticks')
sns.set_palette('colorblind')

# 예제 데이터 불러오기
df_peng = sns.load_dataset('penguins')
df_peng.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1           18.7              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5           17.4              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3           18.0              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN            NaN                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0       3450.0  Female

# %%
fig, ax = plt.subplots(figsize=(5, 5), constrained_layout=True)
sns.regplot(x='bill_length_mm', y='bill_depth_mm', data=df_peng, ax=ax)
# scatter plot, regression line, confidence band를 한 번에 그리는 기능입니다.

fig.savefig('103_snsreglmplot_01.png')

# %%
fig, ax = plt.subplots(figsize=(5, 5), constrained_layout=True)
sns.regplot(x='bill_length_mm', y='bill_depth_mm', data=df_peng, ax=ax,
            scatter_kws={'fc': 'b', 'ec': 'b', 's': 100, 'alpha': 0.3}
            , color='r', line_kws={'lw':3, 'ls':'--', 'alpha': 0.5})

ci = ax.get_children()[2] # confidence band 추출
ci.set(fc='yellow', ec='orange', alpha=0.8) # face & edge color, alpha 조정

fig.savefig('103_snsreglmplot_04.png')

# %%
# 심슨의 역설

fig, axs = plt.subplots(ncols=2, figsize=(10, 4), constrained_layout=True,
                        sharex=True, sharey=True)
# (A) 전체 시각화
sns.regplot(x='bill_length_mm', y='bill_depth_mm', data=df_peng, ax=axs[0], color='k',
            scatter_kws={'fc': 'lightgray', 'ec': 'gray', 's': 50})

# (B) species별 그룹 시각화
peng_species = df_peng['species'].unique()
for species in peng_species:
    df_s = df_peng.loc[df_peng['species'] == species]
    sns.regplot(x='bill_length_mm', y='bill_depth_mm', data=df_s, ax=axs[1], label=species,
                scatter_kws={'s':50, 'alpha':0.5})

axs[1].legend(loc='center left', bbox_to_anchor=[1, 0.5], frameon=False)
axs[1].set_ylabel(' \n')

fig.savefig('103_snsreglmplot_05.png')

# %%
g = sns.lmplot(x='bill_length_mm', y='bill_depth_mm', data=df_peng, hue='species',
               height=5, aspect=1,
               scatter_kws={'s': 50, 'alpha': 0.5})
fig = g.fig
fig.savefig('103_snsreglmplot_06.png')

# %%
# Figure-level function의 장점은 따로 있습니다.
# categorical feature의 class를 FacetGrid로 쉽게 구현할 수 있다는 것임니다.
# col과 row에 열과 행을 나눌 categorical feature 이름을 입력합니다.

# 여기서 g는 Figure보다 상위에 있는 Grid 객체임.
g = sns.lmplot(x='bill_length_mm', y='bill_depth_mm', data=df_peng,
               col='species', row='sex',
               truncate=False, scatter_kws={'s':50, 'alpha':0.5})
fig = g.fig
fig.savefig('103_snsreglmplot_08.png')

# %%
g = sns.lmplot(x='bill_length_mm', y='bill_depth_mm',
               data=df_peng,
               col='species', row='sex',
               scatter_kws={'s': 50})
axes = g.axes # grid > figure > axes
for ax in axes.ravel():
    sns.regplot(x='bill_length_mm', y='bill_depth_mm', data=df_peng,
                fit_reg=False,
                scatter_kws={'fc': 'gray', 'ec': 'none', 's': 50, 'alpha': 0.3}, ax=ax)

fig = g.fig
fig.tight_layout()
fig.savefig('103_snsreglmplot_09.png')

# %%
import matplotlib.colors as mcolors
import colorsys

# matplotlib 기능을 이용해 hue, lightness, saturation을 조정하는 modify_hls() 함수를 먼저 만듭니다.
def modify_hls(c, dh=0, dl=0, ds=0):
    if isinstance(c, str):
        c = mcolors.to_rgb(c)
    h, l, s = colorsys.rgb_to_hls(*c)
    h = h + dh
    l = max(min(l + dl, 1), 0)
    s = max(min(s + ds, 1), 0)
    return colorsys.hls_to_rgb(h, l, s)

# %%
g = sns.lmplot(x='bill_length_mm', y='bill_depth_mm',
               data=df_peng,
               col='species', row='sex',
               scatter_kws={'s': 50})

axes = g.axes
for i, ax in enumerate(axes.ravel()):
    scatter, reg, cb = ax.get_children()[:3]
    if i > 2:
        i -= 3
        dh = -0.05
    else:
        dh = 0
    scatter.set(fc=modify_hls(f'C{i}', dl=0.3, dh=dh), ec=modify_hls(f'C{i}', dh=dh), alpha=1)
    reg.set_color(modify_hls(f'C{i}', dh=dh))
    cb.set(fc=modify_hls(f'C{i}', dl=0.3, dh=dh), ec=modify_hls(f'C{i}', dh=dh))
    sns.regplot(x='bill_length_mm', y='bill_depth_mm', data=df_peng,
                fit_reg=False,
                scatter_kws={'fc': 'gray', 'ec': 'none', 's': 50, 'alpha': 0.3}, ax=ax)
    title = ax.get_title()
    ax.set_title(title, color=modify_hls(f'C{i}', dh=dh))

fig = g.fig
fig.tight_layout()
fig.savefig('103_snsreglmplot_10.png')
